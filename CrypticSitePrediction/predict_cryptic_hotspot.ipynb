# %% [markdown]
# # 🔍 Cryptic Hotspot Prediction Using Optimized AdaBoost Model
#
# This notebook loads a pre-trained AdaBoost model and predicts cryptic hotspots based on user-provided feature data.
#
# ## 📝 How to Use
# 1. Prepare your input feature file (CSV format).
# 2. Please make sure your feature file has the **same column names and order** as the provided `sample_features.csv`. You can use it as a template to format your own data.
# 3. Run all cells below to get prediction results.
# 4. Output will be saved as `prediction_output.csv`.

# %%
#  Import libraries
import pandas as pd
import joblib

#  Optional: display all columns
pd.set_option('display.max_columns', None)

# %%
#  Load input feature file
input_file = "sample_features.csv"  # Replace with your filename

df_input = pd.read_csv(input_file)
X_input = df_input.drop(columns=["PatchID"], errors="ignore")  # Adjust if needed
df_input.head()
# Out:
#   PatchID  ProbeNumber  A00  A01  A20  A37  B71  E20       gfe         size  \
# 0  Patch1            5    1    1    1    1    1    0 -2.245400  2291.933400
# 1  Patch2            1    0    0    0    0    1    0 -2.754000  1419.269000
# 2  Patch3            6    1    1    1    1    1    1 -2.516833  3710.262500
# 3  Patch4            5    1    1    1    1    1    0 -2.516600  1804.270600
# 4  Patch5            3    0    1    1    0    1    0 -2.242000  1983.486333
#
#    protrusion  convexity  compactness  hydrophobicity  charge_density  \
# 0      0.4592     0.0188     8.896200        0.215800       -0.016400
# 1      0.6110     0.0210     7.009000        0.347000       -0.016000
# 2      0.4120     0.0180    11.135000        0.548500       -0.016500
# 3      0.1732     0.0188     9.031000        0.345200       -0.020400
# 4      0.3450     0.0200     8.119667        0.361667       -0.016333
#
#    flexibility_A00  flexibility_A01  flexibility_A20  flexibility_A37  \
# 0            1.587            1.349            1.447            1.400
# 1            2.094            1.755            1.883            1.872
# 2            1.308            1.120            1.172            1.222
# 3            1.003            0.974            0.742            0.994
# 4            0.849            0.903            0.889            0.847
#
#    flexibility_B71  flexibility_E20  size_water  protrusion_water  \
# 0            1.505            1.593    1619.207             0.514
# 1            1.971            2.043    1021.397             0.675
# 2            1.303            1.355    2210.005             0.490
# 3            0.723            1.006    1085.870             0.220
# 4            0.851            0.825    1142.965             0.321
#
#    convexity_water  compactness_water  hydrophobicity_water  \
# 0            0.019              7.556                 0.314
# 1            0.020              5.647                 0.369
# 2            0.017             10.089                 0.541
# 3            0.019              8.028                 0.308
# 4            0.019              6.502                 0.335
#
#    charge_density_water  flexibility_water
# 0                -0.017              1.672
# 1                -0.018              2.002
# 2                -0.016              1.554
# 3                -0.021              1.213
# 4                -0.019              0.844

# %%
#  Load pre-trained model
model = joblib.load("cryptothml.pkl")

# %%
#  Make predictions
df_input["predicted_label"] = model.predict(X_input)
df_input["predicted_proba"] = model.predict_proba(X_input)[:, 1]

# %%
#  Save and display results
df_input.to_csv("prediction_output.csv", index=False)
df_input[["PatchID", "predicted_label", "predicted_proba"]].head()
# Out:
#   PatchID  predicted_label  predicted_proba
# 0  Patch1                0         0.126321
# 1  Patch2                0         0.163373
# 2  Patch3                0         0.428299
# 3  Patch4                0         0.149053
# 4  Patch5                0         0.129218
